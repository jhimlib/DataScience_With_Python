# %%
#import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
#renerate random numbers(total 10)
randomnumber=np.random.rand(10)

# %%
#view data
randomnumber
# Out:
# array([0.5600729 , 0.53679389, 0.31369872, 0.31830908, 0.9428451 ,
#        0.32256818, 0.64491315, 0.37791039, 0.77344965, 0.56858068])

# %%
#select style of the plot
style.use('ggplot')
#Plot the random number
plt.plot(randomnumber,'g',label='line one',linewidth=2)
#x axis is number of random numbers (index)
plt.xlabel('Range')
#y axis is actual randon numbers
plt.ylabel('Numbers')
#title of the plot
plt.title('First Plot')
plt.legend()
plt.show()
