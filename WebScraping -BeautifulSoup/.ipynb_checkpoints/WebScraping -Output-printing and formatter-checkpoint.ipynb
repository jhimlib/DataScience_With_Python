# %%
#import necessary libraries
from bs4 import BeautifulSoup
import requests

# %%
#define url for simplelearn
url="http://yahoo.com"

# %%
#access result through request object
result=requests.get(url)
#load the page content
page_content = result.content
#create soup object
soup=BeautifulSoup(page_content,'html.parser')
result.close()

# %%
#view the contents
soup.contents
# Out:
# ['html',
#  '\n',
#  <html class="atomic my3columns l-out Pos-r https fp fp-v2 rc1 fp-default mini-uh-on viewer-right two-col ntk-wide ltr desktop Desktop bkt201" id="atomic" lang="en-US">
#  <head>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#  <title>Yahoo</title><meta content="on" http-equiv="x-dns-prefetch-control"/><link href="//s.yimg.com" rel="dns-prefetch"/><link href="//s.yimg.com" rel="preconnect"/><link href="//search.yahoo.com" rel="dns-prefetch"/><link href="//search.yahoo.com" rel="preconnect"/><link href="//csc.beap.bc.yahoo.com" rel="dns-prefetch"/><link href="//csc.beap.bc.yahoo.com" rel="preconnect"/><link href="//geo.yahoo.com" rel="dns-prefetch"/><link href="//geo.yahoo.com" rel="preconnect"/><link href="//video-api.yql.yahoo.com" rel="dns-prefetch"/><link href="//video-api.yql.yahoo.com" rel="preconnect"/> <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# ...

# %%
#prettify the output
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Online Certification Training Courses for Professionals | Simplilearn
#   </title>
#   <link href="https://ssl.google-analytics.com" rel="dns-prefetch"/>
#   <link href="https://js-agent.newrelic.com" rel="dns-prefetch"/>
#   <link href="https://rum-static.pingdom.net" rel="dns-prefetch"/>
#   <script type="text/javascript">
# ...

# %%
#view the original encoding
soup.original_encoding
# Out:
# 'utf-8'

# %%
#format the tag a to xml
soup.body.a.prettify(formatter='xml')
# Out:
# '<a class="D(ib) Bgr(nr) logo-datauri W(190px) H(45px) Bgp($twoColLogoPos) Bgz(190px) Bgp($twoColLogoPosSM)!--sm1024 Bgz(90px)!--sm1024 ua-ie7_Bgi($logoImageIe) ua-ie7_Mstart(-185px) ua-ie8_Bgi($logoImageIe) ua-ie9_Bgi($logoImageIe)" data-ylk="rspns:nav;t1:a1;t2:hd;sec:hd;itc:0;slk:logo;elm:img;elmt:logo;" href="https://www.yahoo.com/" id="uh-logo" style="background-image:url(https://s.yimg.com/cv/apiv2/YahooHolidayLogo_HispanicHeritageMonth/Yahoo_HispanicHeritage_Logo_Desktop.png)" tabindex="1">\n <b class="Hidden">\n  Yahoo\n </b>\n</a>\n'

# %%
#define a custom function to convert string values to uppercase
def upperCaseFn(strtext):
    return strtext.upper()

#format using function
soup.body.a.prettify(formatter=upperCaseFn)
# Out:
# '<a class="D(IB) BGR(NR) LOGO-DATAURI W(190PX) H(45PX) BGP($TWOCOLLOGOPOS) BGZ(190PX) BGP($TWOCOLLOGOPOSSM)!--SM1024 BGZ(90PX)!--SM1024 UA-IE7_BGI($LOGOIMAGEIE) UA-IE7_MSTART(-185PX) UA-IE8_BGI($LOGOIMAGEIE) UA-IE9_BGI($LOGOIMAGEIE)" data-ylk="RSPNS:NAV;T1:A1;T2:HD;SEC:HD;ITC:0;SLK:LOGO;ELM:IMG;ELMT:LOGO;" href="HTTPS://WWW.YAHOO.COM/" id="UH-LOGO" style="BACKGROUND-IMAGE:URL(HTTPS://S.YIMG.COM/CV/APIV2/YAHOOHOLIDAYLOGO_HISPANICHERITAGEMONTH/YAHOO_HISPANICHERITAGE_LOGO_DESKTOP.PNG)" tabindex="1">\n <b class="HIDDEN">\n  YAHOO\n </b>\n</a>\n'

# %%
#view the head of the web document
soup.head
# Out:
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Yahoo</title><meta content="on" http-equiv="x-dns-prefetch-control"/><link href="//s.yimg.com" rel="dns-prefetch"/><link href="//s.yimg.com" rel="preconnect"/><link href="//search.yahoo.com" rel="dns-prefetch"/><link href="//search.yahoo.com" rel="preconnect"/><link href="//csc.beap.bc.yahoo.com" rel="dns-prefetch"/><link href="//csc.beap.bc.yahoo.com" rel="preconnect"/><link href="//geo.yahoo.com" rel="dns-prefetch"/><link href="//geo.yahoo.com" rel="preconnect"/><link href="//video-api.yql.yahoo.com" rel="dns-prefetch"/><link href="//video-api.yql.yahoo.com" rel="preconnect"/> <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# ...

# %%
#view title of the web page
soup.title
# Out:
# <title>Yahoo</title>

# %%
#find all the links present on the web page
for href in soup.findAll('a',href=True):
    print(href['href'])
# Out:
# https://www.yahoo.com/
# https://login.yahoo.com/config/login?.src=fpctx&.intl=us&.lang=en-US&.done=https%3A%2F%2Fwww.yahoo.com
# https://mail.yahoo.com/?.src=fp
# https://login.yahoo.com/config/login?.src=fpctx&.intl=us&.lang=en-US&.done=https%3A%2F%2Fwww.yahoo.com
# #mega-bottombar-mail
# #Main
# #Aside
# https://mail.yahoo.com/?.src=fp
# https://news.yahoo.com/
# https://finance.yahoo.com/
# https://sports.yahoo.com/
# https://news.yahoo.com/politics/
# https://www.yahoo.com/entertainment/
# https://www.yahoo.com/lifestyle/
# https://www.yahoo.com/everything/
# https://www.yahoo.com/gma/trump-call-ukraine-center-inspector-general-complaint-sources-010239379.html
# https://www.yahoo.com/gma/trump-call-ukraine-center-inspector-general-complaint-sources-010239379.html
# https://www.yahoo.com/gma/least-4-dead-utah-tour-bus-crash-officials-184700280--abc-news-topstories.html
# https://news.yahoo.com/skip-school-strike-students-across-114236428.html
# ...
